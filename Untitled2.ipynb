# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import norm

# Generate normal distribution data
mean = 50
std_dev = 10
data = np.random.normal(mean, std_dev, 1000)

# Descriptive statistics
print("Mean:", np.mean(data))
print("Median:", np.median(data))
print("Variance:", np.var(data))
print("Standard Deviation:", np.std(data))

# Plot histogram
plt.hist(data, bins=30, density=True)

# PDF curve
x = np.linspace(min(data), max(data), 100)
plt.plot(x, norm.pdf(x, mean, std_dev))

plt.title("Normal Distribution")
plt.show()

# Coin toss simulation
tosses = 1000
results = np.random.choice([0, 1], size=tosses)

heads = np.sum(results)
tails = tosses - heads

print("Heads:", heads)
print("Tails:", tails)
print("P(Heads):", heads/tosses)
print("P(Tails):", tails/tosses)
# Out:
# Mean: 50.01657449005547
# Median: 50.232309570802855
# Variance: 96.74556325214965
# Standard Deviation: 9.835932251299297
# Heads: 492
# Tails: 508
# P(Heads): 0.492
# P(Tails): 0.508
